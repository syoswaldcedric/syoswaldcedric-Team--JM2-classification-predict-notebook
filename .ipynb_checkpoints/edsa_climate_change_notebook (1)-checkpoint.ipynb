# %% [markdown]
#    # Team JM2 Classification Predict Student Solution
#    # Climate Change Belief Analysis 2022
# ---

# %% [markdown]
# © Explore Data Science Academy
#
# ### Honour Code
#
# ---
#
# We {**TEAM JM2**}, confirm - by submitting this document - that the solutions in this notebook are a result of our own work and that we abide by the [EDSA honour code](https://drive.google.com/file/d/1QDCjGZJ8-FmJE3bZdIQNwnJyQKPhHZBn/view?usp=sharing).
#
# Non-compliance with the honour code constitutes a material breach of contract

# %% [markdown]
# ![climate.avif](attachment:climate.avif)

# %% [markdown]
# ### Predict Overview: Climate Change Belief Analysis 2022
#
#
#
# Many companies are built around lessening one’s environmental impact or carbon footprint. They offer products and services that are environmentally friendly and sustainable, in line with their values and ideals. They would like to determine how people perceive climate change and whether or not they believe it is a real threat. This would add to their market research efforts in gauging how their product/service may be received.
#
# With this context, EDSA is challenging you during the Classification Sprint with the task of creating a Machine Learning model that is able to classify whether or not a person believes in climate change, based on their novel tweet data.
#
# Providing an accurate and robust solution to this task gives companies access to a broad base of consumer sentiment, spanning multiple demographic and geographic categories - thus increasing their insights and informing future marketing strategies.

# %% [markdown]
# <a id="cont"></a>
#
# ## Table of Contents
#
# <a href=#one>1. Importing Packages</a>
#
# <a href=#two>2. Loading Data</a>
#
# <a href=#three>3. Pre-processing of the datasets</a>
#
# <a href=#four>4. Exploratory Data Analysis (EDA)</a>
#
# <a href=#five>5. Data Engineering</a>
#
# <a href=#six>6. Modeling</a>
#
# <a href=#seven>7. Model Performance</a>
#
# <a href=#seven>8. Model Explanations</a>
#
# <a href=#seven>9. Conclusion</a>

# %% [markdown]
#  <a id="one"></a>
# # 1. Importing Packages
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Importing Packages ⚡ |
# | :--------------------------- |
# | In this section we imported and briefly discussed the libraries that will be used throughout the analysis and modelling. |
#
# ---

# %% [markdown]
# ### 1.1. Data analysis Packages
# To analyze the the data we will need the following packages
# <ul>
#     <li><b>Numpy</b></li>
#     Numpy is a packages used to perform a wide variety of mathematical operations on arrays. It adds powerful data structures to Python that guarantee efficient calculations with arrays and matrices and it supplies an enormous library of high-level mathematical functions that operate on these arrays and matrices.<br>
#     <li><b>Pandas</b></li>
#     Pandas is mainly used for data analysis and associated manipulation of tabular data in Dataframes. Pandas allows importing data from various file formats such as comma-separated values, JSON, Parquet, SQL database tables or queries, and Microsoft Excel.
#     <li><b>Matplotlib</b></li>
#     Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. It is a cross-platform library for making 2D plots from data in arrays. It provides an object-oriented API that helps in embedding plots in applications using Python GUI toolkits such as PyQt, WxPythonotTkinter.
#     <li><b>Seaborn</b></li>
#     Seaborn is a library for making statistical graphics in Python. It builds on top of matplotlib and integrates closely with pandas data structures. Seaborn helps you explore and understand your data.
#     <li><b>Wordcloud</b></li>
#     A wordcloud is a collection, or cluster, of words depicted in different sizes. The bigger and bolder the word appears, the more often it’s mentioned within a given text and the more important it is.
# </ul>

# %%
# Libraries for data loading, data manipulation and data visulisation
import pandas as pd      
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud
# set plot style
sns.set()

# %% [markdown]
# ### 1.2. Data Preparation Packages
# Before fitting the model to the data it is necessary to do some work on it. THe following packages will help achieve that.
#
# <ul>
#     <li><b>stopwords</b></li>
#     Decision trees regression normally use mean squared error (MSE) to decide to split a node in two or more sub-nodes. Suppose we are doing a binary tree the algorithm first will pick a value, and split the data into two subset. For each subset, it will calculate the MSE separately.
#     <li><b>tokenizer</b></li>
#     A random forest regressor. A random forest is a meta estimator that fits a number of classifying decision trees on various sub-samples of the dataset and uses averaging to improve the predictive accuracy and control over-fitting.
#     <li><b>WordNetLemmatizer</b></li>
#     A voting regressor is an ensemble meta-estimator that fits several base regressors, each on the whole dataset. Then it averages the individual predictions to form a final prediction.
#     <li><b>CountVectorizer</b></li>
#     Stacked generalization consists in stacking the output of individual estimator and use a regressor to compute the final prediction.
#     <li><b>PorterStemmer</b></li>
#     A Bagging regressor is an ensemble meta-estimator that fits base regressors each on random subsets of the original dataset and then aggregate their individual predictions (either by voting or by averaging) to form a final prediction.
#     <li><b>SVM</b></li>
#     Support vector machines (SVMs) are a set of supervised learning methods used for classification, regression and outliers detection. The advantages of support vector machines are: Effective in high dimensional spaces. Still effective in cases where number of dimensions is greater than the number of samples.
#     <li><b>Seaborn</b></li>
#     Seaborn is a library for making statistical graphics in Python. It builds on top of matplotlib and integrates closely with pandas data structures. Seaborn helps you explore and understand your data.
# </ul>

# %%
import nltk   #Importing nltk
from nltk.corpus import stopwords  #importing Stopwords
import string
from nltk.tokenize import word_tokenize, TreebankWordTokenizer
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer
from nltk import SnowballStemmer, PorterStemmer, LancasterStemmer
import pickle

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 1.3. Data Engineering Packages

# %%
from sklearn.utils import resample
from nltk.util import ngrams
from imblearn.over_sampling import SMOTE 
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ### 1.4. Machine Learning Packages
# To analyze the data we will need the following packages
# <ul>
#     <li><b>train_test_split</b></li> train_test_split is a model validation procedure that allows you to simulate how a model would perform on new/unseen data.
#     <li><b>LogisticRegression</b></li> Logistic regression is a statistical analysis method to predict a binary outcome, such as yes or no, based on prior observations of a data set.
#     <li><b>DecisionTreeClassifier</b></li> DecisionTreeClassifier is a class capable of performing multi-class classification on a dataset.
#     <li><b>XGBClassifier</b></li> XGBoost, which stands for Extreme Gradient Boosting, is a scalable, distributed gradient-boosted decision tree (GBDT) machine learning library. It provides parallel tree boosting and is the leading machine learning library for regression, classification, and ranking problems.
#     <li><b>CatBoostClassifier</b></li> CatBoost is an algorithm for gradient boosting on decision trees. It is developed by Yandex researchers and engineers, and is used for search, recommendation systems, personal assistant, self-driving cars, weather prediction and many other tasks at Yandex and in other companies, including CERN, Cloudflare, Careem taxi. It is in open-source and can be used by anyone. The CatBoost library can be used to solve both classification and regression challenge.
#     <li><b>VotingClassifier</b></li> A voting classifier is a machine learning estimator that trains various base models or estimators and predicts on the basis of aggregating the findings of each base estimator.
# </ul>

# %%
# Libraries for data preparation and model building
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier 
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.svm import SVC
from sklearn.ensemble import VotingClassifier

# Model performance metric libraries
from sklearn.metrics import f1_score, precision_score, recall_score, confusion_matrix
from sklearn.metrics import classification_report

# %% [markdown]
# ### 1.5. Other Packages
# To analyze the the data we will need the following packages
# <ul>
#     <li><b>Pickle</b></li>
#     Pickle in Python is primarily used in serializing and deserializing a Python object structure. In other words, it's the process of converting a Python object into a byte stream to store it in a file/database, maintain program state across sessions, or transport data over the network.
#     <li><b>Metrics</b></li>
#     The sklearn. metrics module implements several loss, score, and utility functions to measure classification performance. Some metrics might require probability estimates of the positive class, confidence values, or binary decisions values.
#     <li><b>Math</b></li>
#     For straightforward mathematical calculations in Python, you can use the built-in mathematical operators, such as addition ( + ), subtraction ( - ), division ( / ), and multiplication ( * ). But more advanced operations, such as exponential, logarithmic, trigonometric, or power functions, are not built in.
# </ul>

# %% [markdown]
# ### 1.6. Comet

# %% [markdown]
# Comet is connected onto this notebook in order to monitor and store metrics, notebook and models.

# %%
#Importing comet library
from comet_ml import Experiment

# Creating an experiment on comet with the api key
experiment = Experiment(
    api_key="GcTv9Oug0ZRsTdoU4iwKxuWPC",
    project_name="climate-change-sentiment-analysis-2022",
    workspace="emmantheo",
)
# Out:
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: xgboost, sklearn. Metrics and hyperparameters can still be logged using comet_ml.log_metrics() and comet_ml.log_parameters()
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/emmantheo/climate-change-sentiment-analysis-2022/8db232e6a09349079ff937ae663921a9

# %% [markdown]
# <a id="two"></a>
# # 2. Loading the Data
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Loading the data ⚡ |
# | :--------------------------- |
# | In this section we are going to load the data from the `train` and  `test_with_no_labels` file into DataFrames. |
#
# ---

# %% [markdown]
# For the pupose of the model development, two datasets have been provided in two csv files
# <ul>
# <li><b>Train Data Set</b></li>
# Training data is an extremely large dataset that is used to teach a machine learning model. Training data is used to teach prediction models that use machine learning algorithms how to extract features that are relevant to specific business goals.
# <li><b>Test Data Set</b></li>
# Test data is data which has been specifically identified for use in tests, typically of a computer program. Some data may be used in a confirmatory way, typically to verify that a given set of input to a given function produces some expected result.
# </ul>
#
# We will load these datasets in two data frames so we can use them for the model development. After loading the data, we will display the head of the dataset to get the first idea of the type of data we are working with.

# %%
#Loading the train dataset
df_train = pd.read_csv('train.csv')
df_train.head(20)
# Out:
#     sentiment                                            message  tweetid
# 0           1  PolySciMajor EPA chief doesn't think carbon di...   625221
# 1           1  It's not like we lack evidence of anthropogeni...   126103
# 2           2  RT @RawStory: Researchers say we have three ye...   698562
# 3           1  #TodayinMaker# WIRED : 2016 was a pivotal year...   573736
# 4           1  RT @SoyNovioDeTodas: It's 2016, and a racist, ...   466954
# 5           1  Worth a read whether you do or don't believe i...   425577
# 6           1  RT @thenation: Mike Pence doesn’t believe in g...   294933
# 7           1  RT @makeandmendlife: Six big things we can ALL...   992717
# 8           1  @AceofSpadesHQ My 8yo nephew is inconsolable. ...   664510
# 9           1  RT @paigetweedy: no offense… but like… how do ...   260471
# 10          1  RT @StephenSchlegel: she's thinking about how ...   295793
# 11          1  I do hope people who are vocal about climate c...   763719
# ...

# %% [markdown]
# From the trained data, it can be observed that we are dealing with text and numeric data. The label is numeric, where;
#
#    2 represents news about climate change
#
#    1 represents pro climate change
#
#    0 represents neutral
#
#  -1 represents anti climate change

# %%
#checking the number of rows and column in our train dataset. 
df_train.shape
# Out:
# (15819, 3)

# %% [markdown]
# The train data contains 15819 observations while there is 3 columns in which we are dropping the third column which represents ID of twitter users. This is because we do not need the ID column.

# %%
#Loading the test dataset
df_test = pd.read_csv('test.csv')
df_test.head(20)
# Out:
#                                               message  tweetid
# 0   Europe will now be looking to China to make su...   169760
# 1   Combine this with the polling of staffers re c...    35326
# 2   The scary, unimpeachable evidence that climate...   224985
# 3   @Karoli @morgfair @OsborneInk @dailykos \r\nPu...   476263
# 4   RT @FakeWillMoore: 'Female orgasms cause globa...   872928
# 5   RT @nycjim: Trump muzzles employees of several...    75639
# 6   @bmastenbrook yes wrote that in 3rd yr Comp Sc...   211536
# 7   RT @climatehawk1: Indonesian farmers weather #...   569434
# 8   RT @guardian: British scientists face a ‘huge ...   315368
# 9   Aid For Agriculture | Sustainable agriculture ...   591733
# 10  There is no climate change, Globalists! https:...    91983
# 11  Biggest threat to our economy is climate chang...    67249
# 12  RT @100isNow: He's CEO of a company that lied ...   143459
# 13  RT @VICE: Venice could be swallowed by water w...   663535
# ...

# %% [markdown]
# From the test data, it can be observed that we are dealing with text and numeric data. Unlike the train data, there is no label column here because that is what we are going to be predicting.

# %%
df_test.shape
# Out:
# (10546, 2)

# %% [markdown]
# The test data contains 10546 observations while there are 2 columns in which we are dropping the second column which represents ID of twitter users. This is because we do not need the ID column.

# %% [markdown]
# <a id="three"></a>
# # 3. Pre-processing of the datasets
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Pre-processing of the datasets ⚡ |
# | :--------------------------- |
# | In this section we are going to perform thorough cleaning of the dataset. Since it is text data, we are going to use the Natural Language Processor (NLP) for this pre-process phase.
#
# ---

# %% [markdown]
# ## 3.1. TRAIN DATASET PRE-PROCESSING

# %% [markdown]
# Before training our model on the given data, we need to make sure the data is clean enough for use. This is because our model is only as good as the data we feed it. Therefore, the first cleaning of the datasets is going to be done on the train dataset then the unseen test data with the use of Natural Language Processor(NLP).

# %%
#Increasing the size of the dataset by separating each of the message in the message column of each row into its own row
all_train = []
for i, row in df_train.iterrows():
    for message in row['message'].split('|||'):
        all_train.append([row['sentiment'], message])
all_train = pd.DataFrame(all_train, columns=['sentiment', 'message']) #dropping the tweetID column

# %% [markdown]
# The dataset increased by 1 after seperating each messages in the message column.

# %%
#checking to see if the column has been dropped
all_train.shape
# Out:
# (15820, 2)

# %% [markdown]
# The tweet ID column was successfully dropped leaving us with only the sentiment(label) and message(feature) columns for our training to be carried out.

# %%
#Initialising the tokenizer and lemmatizer
tokeniser = TreebankWordTokenizer()
lemmatizer = WordNetLemmatizer()

# %% [markdown]
# ### 3.1.1. Noise Removal

# %%
#Creating a function for noise removal
def noise_removal(df, message):
    '''this function helps in the removal of noises from our dataset'''
    
    pattern_url = r'http[s]?://(?:[A-Za-z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9A-Fa-f][0-9A-Fa-f]))+'
    subs_url = r'url-web'
    df['message'] = df['message'].replace(to_replace = pattern_url, 
                                          value = subs_url, regex = True)
    return df['message']

# %%
#removing noise from the train dataset
all_train['message'] = noise_removal(all_train, message)

# %% [markdown]
# Noises such as symbols, special characters and web links were successfully removed from the data in order to make the data clean.

# %% [markdown]
# ### 3.1.2. Punctuation Removal

# %% [markdown]
# There are punctuations in our text data that need to be removed in order to make our dataset clean and ready for training. In this section, we are going to remove these punctuations.

# %%
#function for removing punctuation
def remove_punctuation(message):
    ''' this function is responsible for removing punctuation '''
    
    return ''.join([j for j in message if j not in string.punctuation])

# %%
#Removing punctuation from train dataset

all_train['message'] = all_train['message'].apply(remove_punctuation)

# %%
#checking to see if punctuations have been removed
all_train['message']
# Out:
# 0        PolySciMajor EPA chief doesnt think carbon dio...
# 1        Its not like we lack evidence of anthropogenic...
# 2        RT RawStory Researchers say we have three year...
# 3        TodayinMaker WIRED  2016 was a pivotal year in...
# 4        RT SoyNovioDeTodas Its 2016 and a racist sexis...
#                                ...
# 15815    RT ezlusztig They took down the material on gl...
# 15816    RT washingtonpost How climate change could be ...
# 15817    notiven RT nytimesworld What does Trump actual...
# 15818    RT sara8smiles Hey liberals the climate change...
# 15819    RT ChetCannon kurteichenwalds climate change e...
# Name: message, Length: 15820, dtype: object

# %% [markdown]
# A function for removal of punctuation was created in order to help remove punctuations. This function is also going to be applied on the test data.
# Punctuations were removed from the train data. We go ahead to tokenize and lemmatize the text. The tokeniser divides text into a sequence of tokens, which roughly correspond to "words". We will use tokenisers to clean up the data, making it ready to be trained.

# %% [markdown]
# ### 3.1.3. Conversion of text to lowercase, tokenizing and lemmatizing

# %%
#creating function for changing all text to lowercase, tokenise text, stemmatize text and lemmatise text
def pre_processor(df, message):
    ''' this function is responsible for converting our text to 
    lowercase, tokenize and also lemmatize it'''
    
    lower_case = df['message'].str.lower()                #converting text to lowercase in order to make cleaning uniform
    tokenised_tweet = lower_case.apply(lambda x: x.split())       #Tokenising the train data
    lemmatized_tweet = tokenised_tweet.apply(lambda sentence: 
                                               [lemmatizer.lemmatize(word) for word in sentence])
    return lemmatized_tweet

# %%
#converting text to lowercase, tokenizing and lemmatizing

all_train['cleaned_tweet'] = pre_processor(all_train, message)

# %%
#variable for cleaned tweet

cleaned_data = all_train['cleaned_tweet']

# %% [markdown]
# Conversion of the text data to lowercase was carried out in order to ensure uniform cleaning of the data.
# The text were successfully tokenized and lemmatize.

# %% [markdown]
# ### 3.1.4. Conversion of each message to sentence

# %%
#combining the cleaned message column into single sentence for the train dataset
for i in range(len(cleaned_data)):
    cleaned_data[i] = " ".join(cleaned_data[i])
all_train['cleaned_tweet'] = cleaned_data

# %%
#checking to see if well combined into sentence
all_train.head(20)
# Out:
#     sentiment                                            message  \
# 0           1  PolySciMajor EPA chief doesnt think carbon dio...
# 1           1  Its not like we lack evidence of anthropogenic...
# 2           2  RT RawStory Researchers say we have three year...
# 3           1  TodayinMaker WIRED  2016 was a pivotal year in...
# 4           1  RT SoyNovioDeTodas Its 2016 and a racist sexis...
# 5           1  Worth a read whether you do or dont believe in...
# 6           1  RT thenation Mike Pence doesn’t believe in glo...
# 7           1  RT makeandmendlife Six big things we can ALL d...
# 8           1  AceofSpadesHQ My 8yo nephew is inconsolable He...
# 9           1  RT paigetweedy no offense… but like… how do yo...
# 10          1  RT StephenSchlegel shes thinking about how she...
# 11          1  I do hope people who are vocal about climate c...
# 12          2  RT tveitdal We only have a 5 percent chance of...
# ...

# %% [markdown]
# From the message column, we derived a new column named 'cleaned_tweet' after going through the preprocessing phase.

# %% [markdown]
# ### 3.2. TEST DATASET PREPROCESSING

# %% [markdown]
# Just like the train dataset, the test dataset needs to be cleaned in order to allow the model to predict better. The test dataset also follows the same pre-processing steps as that of the train data.

# %% [markdown]
# ### 3.2.1. Noise Removal

# %%
df_test['message'] = noise_removal(df_test, message)

# %% [markdown]
# Noises such as symbols, special characters and web links were successfully removed from the test data in order to make the data clean.

# %% [markdown]
# ### 3.2.2. Punctuation Removal

# %%
#Removing punctuation from test dataset

df_test['message'] = df_test['message'].apply(remove_punctuation)

# %%
df_test['message']
# Out:
# 0        Europe will now be looking to China to make su...
# 1        Combine this with the polling of staffers re c...
# 2        The scary unimpeachable evidence that climate ...
# 3        Karoli morgfair OsborneInk dailykos \r\nPutin ...
# 4        RT FakeWillMoore Female orgasms cause global w...
#                                ...
# 10541    RT BrittanyBohrer Brb writing a poem about cli...
# 10542    2016 the year climate change came home During ...
# 10543    RT loopvanuatu Pacific countries positive abou...
# 10544    RT xanria00018 You’re so hot you must be the c...
# 10545    RT chloebalaoing climate change is a global is...
# Name: message, Length: 10546, dtype: object

# %% [markdown]
# Punctuations were removed from the test data. We go ahead to tokenize, stemmatize and lemmatize the text.
# The tokeniser divides the text into a sequence of tokens, which roughly correspond to "words". We will use
# tokenisers, stemmatizer and lemmatizer to clean up the test data, making it ready for prediction.

# %% [markdown]
# ### 3.2.3. Conversion of text to lowercase, tokenizing, stemmatizing and lemmatizing

# %%
#converting to lowercase, tokenizing and lemmatization of the text

df_test['cleaned_tweet'] = pre_processor(df_test, message)

# %%
#checking the cleaned_tweet test data to see if text has been tokenized, stemmatized and lemmatized

df_test['cleaned_tweet']
# Out:
# 0        [europe, will, now, be, looking, to, china, to...
# 1        [combine, this, with, the, polling, of, staffe...
# 2        [the, scary, unimpeachable, evidence, that, cl...
# 3        [karoli, morgfair, osborneink, dailykos, putin...
# 4        [rt, fakewillmoore, female, orgasm, cause, glo...
#                                ...
# 10541    [rt, brittanybohrer, brb, writing, a, poem, ab...
# 10542    [2016, the, year, climate, change, came, home,...
# 10543    [rt, loopvanuatu, pacific, country, positive, ...
# 10544    [rt, xanria00018, you’re, so, hot, you, must, ...
# 10545    [rt, chloebalaoing, climate, change, is, a, gl...
# Name: cleaned_tweet, Length: 10546, dtype: object

# %% [markdown]
# Conversion of the text to lowercase was carried out in order to ensure uniform cleaning of the data.
# Just like the train data, the test dataset was tokenized, stemmatized and lemmatized accordingly.

# %%
#assigning a variable to the cleaned_tweet dataframe
cleaned_data = df_test['cleaned_tweet']

# %% [markdown]
# ### 3.2.4. Conversion of each message to sentence

# %%
#combining the cleaned message column into single sentence for the train dataset
for i in range(len(cleaned_data)):
    cleaned_data[i] = " ".join(cleaned_data[i])
df_test['cleaned_tweet'] = cleaned_data

# %%
#checking to see if well combined into sentence
df_test.head()
# Out:
#                                              message  tweetid  \
# 0  Europe will now be looking to China to make su...   169760
# 1  Combine this with the polling of staffers re c...    35326
# 2  The scary unimpeachable evidence that climate ...   224985
# 3  Karoli morgfair OsborneInk dailykos \r\nPutin ...   476263
# 4  RT FakeWillMoore Female orgasms cause global w...   872928
#
#                                        cleaned_tweet
# 0  europe will now be looking to china to make su...
# 1  combine this with the polling of staffer re cl...
# 2  the scary unimpeachable evidence that climate ...
# 3  karoli morgfair osborneink dailykos putin got ...
# 4  rt fakewillmoore female orgasm cause global wa...

# %% [markdown]
# <a id="three"></a>
# # 4. Exploratory Data Analysis (EDA)
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Exploratory data analysis ⚡ |
# | :--------------------------- |
# | In this section we are going to perform an in-depth analysis of all the variables in the DataFrame. This would give us proper knowledge of our feature and label to know how useful they are to this project.
#
# ---

# %% [markdown]
# ## 4.1. Analysing the label

# %%
#checking to see the classes in the label

sentiment_labels = list(df_train.sentiment.unique())
sentiment_labels
# Out:
# [1, 2, 0, -1]

# %% [markdown]
# There are four classes in the label, which shows this is a multi-classification machine learning problem.

# %%
#distribution of the classes in the label

df_train['sentiment'].value_counts().plot(kind = 'bar')
plt.show()

# %% [markdown]
# From the distribution, it can be seen that the classes in the label are imbalanced. The pro which is represented by 1 is way more than the news(2), neutral(0) and anti(-1).Therefore, to avoid the prediction from being biased, we are going to balance the classes later in the data engineering section.

# %%
# Separating minority and majority classes
neutral = df_train[df_train['sentiment']==0]
pro = df_train[df_train['sentiment']==1]
anti = df_train[df_train['sentiment']== -1]
news = df_train[df_train['sentiment']== 2]

# %%
#checking the percentage of people who believe in climate change
pro_percent = len(pro)/ (len(neutral)+len(pro)+len(anti)+len(news))
pro_percent
# Out:
# 0.5392249826158417

# %%
#checking the percentage of people who do not believe in climate change
anti_percent = len(anti)/ (len(neutral)+len(pro)+len(anti)+len(news))
anti_percent
# Out:
# 0.08192679688981605

# %%
#checking the percentage of people who are indifferent about climate change
neutral = len(neutral)/ (len(neutral)+len(believe)+len(not_believe)+len(news))
neutral
# Out:
# 0.1487451798470194

# %% [markdown]
# From the above analysis, we can see that the classes in our response variable is not balanced. The pro is made up of 53.9 percent of the label column while the anti only contains 8.19 percent of the label. This can greatly lead to bias in prediction by our model because it is going to be more exposed to the pro sentiment than the other sentiments. Therefore we need to balance it during the Data Engineering part of our work.

# %% [markdown]
# ## 4.2. VISUALS

# %% [markdown]
# In this subsection, we are going to visualise the most occuring words in each classes of the label. These words help our model to be well trained in order to be able to predict on the test data.

# %%
#visualising the frequent words in the train dataset
all_words = " ".join([sentence for sentence in all_train['cleaned_tweet']])
wordcloud = WordCloud(width= 800, height = 500, random_state= 42, max_font_size= 100).generate(all_words)

# %%
#Ploting the graph
plt.figure(figsize = (15, 8))
plt.imshow(wordcloud, interpolation = 'blackman')
plt.axis('off')
plt.show()

# %% [markdown]
# From the visuals above, it can be seen that the bigger the words, the more dominant they are. The following list of words/phrases are among the dominant words;
#
# Climate Change
#
# Global Warming
#
# Change
#
# Urlweb
#
# Planet
#
# donald trump

# %%
##for frequent words in belief of climate change
all_words = " ".join([sentence for sentence in all_train['cleaned_tweet'][all_train['sentiment']==1]])
wordcloud = WordCloud(width= 800, height = 500, random_state= 42, max_font_size= 100).generate(all_words)

# %%
## Ploting the graph
plt.figure(figsize = (15, 8))
plt.imshow(wordcloud, interpolation = 'blackman')
plt.axis('off')
plt.show()

# %% [markdown]
# From the visual above, it can be seen that the following words/phrases were frequently used by people who believe climate change exists;
#
# Climate Change
#
# Environment
#
# Believe
#
# tackle climate
#
# think climate
#
# fight climate
#
# global warming

# %%
##for frequent words not in belief of climate change
all_words = " ".join([sentence for sentence in all_train['cleaned_tweet'][all_train['sentiment']==-1]])
wordcloud = WordCloud(width= 800, height = 500, random_state= 42, max_font_size= 100).generate(all_words)

# %%
## Ploting the graph
plt.figure(figsize = (15, 8))
plt.imshow(wordcloud, interpolation = 'blackman')
plt.axis('off')
plt.show()

# %% [markdown]
# From the visual above, it can be seen that the following words/phrases were frequently used by people who do not believe climate change exists;
#
# Climate Change
#
# hoax
#
# scam
#
# fake
#
# alarmist
#
# manmade climate
#
# agenda

# %%
##for frequent words of neutrals of climate change
all_words = " ".join([sentence for sentence in all_train['cleaned_tweet'][all_train['sentiment']==0]])
wordcloud = WordCloud(width= 800, height = 500, random_state= 42, max_font_size= 100).generate(all_words)

# %%
## Ploting the graph
plt.figure(figsize = (15, 8))
plt.imshow(wordcloud, interpolation = 'blackman')
plt.axis('off')
plt.show()

# %% [markdown]
# For the neutrals, the frequent words/phrases used are listed below;
#
# going
#
# never
#
# club penguin
#
# really
#
# The words in this class do not really show if people believe in climate change or not.

# %%
##for frequent words for news of climate change
all_words = " ".join([sentence for sentence in all_train['cleaned_tweet'][all_train['sentiment']==2]])
wordcloud = WordCloud(width= 800, height = 500, random_state= 42, max_font_size= 100).generate(all_words)

# %%
## ploting the graph
plt.figure(figsize = (15, 8))
plt.imshow(wordcloud, interpolation = 'blackman')
plt.axis('off')
plt.show()

# %% [markdown]
# From the visual above, it can be seen that this class is obviously news category. The following words/phrases show it is news;
#
# urlweb
#
# paris agreement
#
# independent
#
# energy department
#
# research
#
# study find
#
# guardian

# %% [markdown]
# <a id="four"></a>
# # 4. Data Engineering
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Data engineering ⚡ |
# | :--------------------------- |
# | In this section we are going to transform the dataset with the help of a vectoriser. This is the phase where we transform our text data to numeric data so that the model can understand it.|
# ---

# %% [markdown]
# Before using model on our data, we need to transform the text data which is the cleaned data to numeric data for our model to be able to use in training and prediction. To do this, we need a count vectoriser.

# %%
#Transforming the cleaned text from the trained data
cv = CountVectorizer(max_features= 10000, ngram_range=(1,2))
X = cv.fit_transform(all_train['cleaned_tweet'])

# %% [markdown]
# The count vectoriser was set to maximum features of 10000 which means the vectoriser is going to use 10000 most frequent words which have been converted to 1s and 0s and split them each into single features. By using fit_transform, we now have X which is ready to be used in the modelling phase.

# %%
#pickling the vectoriser and storing for later use during development of our app
model_save_path = "countVector.pkl"
with open(model_save_path,'wb') as file:
    pickle.dump(cv,file)

# %%
#Transforming the cleaned text from the test data
bow_test = cv.transform(df_test['cleaned_tweet'])

# %% [markdown]
# The cleaned test data was transformed to numeric data in order to be fed to our model and make predictions.

# %%
#assigning a variable to our label
y = all_train['sentiment']

# %% [markdown]
# We assigned our label to y variable so we can use it smoothly during the modelling phase.

# %%
#using SMOTE for upsampling our classes
smt = SMOTE(random_state = 1, k_neighbors = 1)

# %% [markdown]
# From the exploratory data analysis phase, we saw that the classes in our label are imbalanced, therefore we are going to balance the data with the use of SMOTE which will automatically help us upsample the classes that are lower to meet the biggest class which is the pro(1) class.

# %%
#fitting X and y variable to the SMOTE
X,y = smt.fit_resample(X, y)

# %% [markdown]
# SMOTE was successfully fitted to the X and y variables.

# %%
#count of the classes in the label
y.value_counts()
# Out:
#  0    8530
#  1    8530
#  2    8530
# -1    8530
# Name: sentiment, dtype: int64

# %%
y.value_counts().plot(kind = 'bar')
plt.show()

# %% [markdown]
# From the bar chart above, we can see our 4 classes have been balanced. We can now proceed to the modelling phase of this work.

# %% [markdown]
# <a id="five"></a>
# # 5. Modelling
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
#
# | ⚡ Description: Modelling ⚡ |
# | :--------------------------- |
# | In this section, we created classification models that are able to accurately predict the sentiments |
#
# ---

# %%
#train-test split
x_train, x_test, y_train, y_test = train_test_split(X, y, 
random_state = 42, test_size = 0.25)

# %% [markdown]
# Before training our data, we need to split the data into two, the train data and the test data. This is just to help us validate our training, hence the name validation technique. 25 percent of our train data is going to be tested after we train our model on the 75 percent of this train data. After all these, we can then use our trained model to predict the unseen test data. A random state of 42 was assigned because it is the default value in the train-test split phase.

# %% [markdown]
# ### 5.1. Logistic Regression Model

# %% [markdown]
# Logistic regression is a supervised learning classification algorithm used to predict the probability of a target variable. The nature of target or dependent variable is dichotomous, which means there would be only two possible classes.

# %%
#Model training using logistic regression
model = LogisticRegression(multi_class='ovr')
model.fit(x_train, y_train)
# Out:
# LogisticRegression(multi_class='ovr')

# %%
#Testing
pred = model.predict(x_test)

# %%
#Predicting the unseen data
model.fit(X, y)
pred_test = model.predict(bow_test)

# %%
#result of the prediction
result_model = pd.DataFrame(pred_test, columns= ['sentiment'])
result_model.head(20)
# Out:
#     sentiment
# 0           1
# 1           1
# 2           1
# 3           1
# 4           0
# 5           2
# 6           1
# 7           1
# 8           2
# 9           1
# 10         -1
# 11          0
# 12          1
# 13          1
# 14          0
# 15          0
# 16          1
# 17          1
# 18         -1
# 19          2

# %%
#creating submission file for kaggle upload
output = pd.DataFrame({"tweetid":df_test['tweetid']})
submission = output.join(result_model)
submission.to_csv("submission.csv", index = False)

# %% [markdown]
# The first model to be trained is the logistic regression because of its good history with classification problems. We needed a multi_class parameter because this is a multiclassification task. We are going to train other models too in order to pick the best model at the end.

# %% [markdown]
# ### 5.2. CatBoost Classification Model

# %% [markdown]
# CatBoost is an algorithm for gradient boosting on decision trees.

# %%
#Model training using catboost model classifier
catbst = CatBoostClassifier(
                          bootstrap_type="Bernoulli",
                          class_weights=[1, 1, 1, 1],
                          loss_function='MultiClass')

# %%
#fitting the model on the train dataset
catbst.fit(x_train, y_train)
# Out:
# Learning rate set to 0.093354
# 0:	learn: 1.3273493	total: 87.8ms	remaining: 1m 27s
# 1:	learn: 1.2804447	total: 185ms	remaining: 1m 32s
# 2:	learn: 1.2424407	total: 282ms	remaining: 1m 33s
# 3:	learn: 1.2093771	total: 396ms	remaining: 1m 38s
# 4:	learn: 1.1821988	total: 498ms	remaining: 1m 39s
# 5:	learn: 1.1578991	total: 609ms	remaining: 1m 40s
# 6:	learn: 1.1388270	total: 725ms	remaining: 1m 42s
# 7:	learn: 1.1200657	total: 826ms	remaining: 1m 42s
# 8:	learn: 1.1064353	total: 911ms	remaining: 1m 40s
# 9:	learn: 1.0932852	total: 1.01s	remaining: 1m 39s
# 10:	learn: 1.0788170	total: 1.1s	remaining: 1m 39s
# 11:	learn: 1.0679204	total: 1.19s	remaining: 1m 38s
# 12:	learn: 1.0586300	total: 1.3s	remaining: 1m 38s
# 13:	learn: 1.0491833	total: 1.39s	remaining: 1m 37s
# 14:	learn: 1.0422123	total: 1.47s	remaining: 1m 36s
# 15:	learn: 1.0359380	total: 1.57s	remaining: 1m 36s
# 16:	learn: 1.0279356	total: 1.65s	remaining: 1m 35s
# 17:	learn: 1.0198685	total: 1.74s	remaining: 1m 34s
# ...

# %%
#Testing
y_pred = catbst.predict(x_test)

# %%
catbst.fit(X, y)
# Out:
# Learning rate set to 0.094734
# 0:	learn: 1.3228786	total: 148ms	remaining: 2m 27s
# 1:	learn: 1.2776128	total: 300ms	remaining: 2m 29s
# 2:	learn: 1.2376088	total: 491ms	remaining: 2m 43s
# 3:	learn: 1.2067065	total: 641ms	remaining: 2m 39s
# 4:	learn: 1.1806847	total: 800ms	remaining: 2m 39s
# 5:	learn: 1.1592418	total: 942ms	remaining: 2m 36s
# 6:	learn: 1.1399027	total: 1.1s	remaining: 2m 36s
# 7:	learn: 1.1212846	total: 1.25s	remaining: 2m 34s
# 8:	learn: 1.1045535	total: 1.41s	remaining: 2m 35s
# 9:	learn: 1.0912036	total: 1.55s	remaining: 2m 33s
# 10:	learn: 1.0798625	total: 1.7s	remaining: 2m 32s
# 11:	learn: 1.0701228	total: 1.82s	remaining: 2m 30s
# 12:	learn: 1.0588259	total: 2s	remaining: 2m 31s
# 13:	learn: 1.0487167	total: 2.14s	remaining: 2m 30s
# 14:	learn: 1.0407041	total: 2.3s	remaining: 2m 31s
# 15:	learn: 1.0317361	total: 2.45s	remaining: 2m 30s
# 16:	learn: 1.0258183	total: 2.59s	remaining: 2m 29s
# 17:	learn: 1.0196106	total: 2.72s	remaining: 2m 28s
# ...

# %%
#predicting the sentiments using the unseen test data
y_pred_test = catbst.predict(bow_test)

# %%
#result of the prediction
result_cat = pd.DataFrame(y_pred_test, columns= ['sentiment'])
result_cat.head(20)
# Out:
#     sentiment
# 0           1
# 1           1
# 2           1
# 3           1
# 4           0
# 5           1
# 6           1
# 7           2
# 8           2
# 9           1
# 10         -1
# 11          1
# 12          1
# 13          2
# 14          1
# 15          0
# 16          1
# 17          1
# 18          1
# 19          2

# %%
#creating submission file for kaggle upload
output = pd.DataFrame({"tweetid":df_test['tweetid']})
submission_cat = output.join(result_model)
submission_cat.to_csv("submission_cat.csv", index = False)

# %% [markdown]
# ### 5.3. Decision Tree Classification Model

# %% [markdown]
# Decision Tree is a Supervised learning technique that can be used for both classification and Regression problems, but mostly it is preferred for solving Classification problems. It is a tree-structured classifier, where internal nodes represent the features of a dataset, branches represent the decision rules and each leaf node represents the outcome.

# %%
#Model training using decision tree model
tree = DecisionTreeClassifier(random_state=42)

# %%
#fitting the model to the train dataset
tree.fit(x_train, y_train)
tree_pred = tree.predict(x_test)

# %%
tree.fit(X, y)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
#predicting sentiments for the unseen test data
tree_pred_test = tree.predict(bow_test)

# %%
#result of the prediction
result_tree = pd.DataFrame(tree_pred_test, columns= ['sentiment'])
result_tree.head(20)
# Out:
#     sentiment
# 0           1
# 1           1
# 2           1
# 3           1
# 4           0
# 5           1
# 6           2
# 7           1
# 8           2
# 9           1
# 10          0
# 11          1
# 12          1
# 13          2
# 14          0
# 15          0
# 16          1
# 17          1
# 18          1
# 19          2

# %%
#creating submission file for kaggle upload
output = pd.DataFrame({"tweetid":df_test['tweetid']})
submission_tree = output.join(result_tree)
submission_tree.to_csv("submission_tree.csv", index = False)

# %% [markdown]
# ### 5.4. Support Vector Machine

# %% [markdown]
# A support vector machine (SVM) is a supervised machine learning model that uses classification algorithms for group classification problems. After giving an SVM model sets of labeled training data for each category, they’re able to categorize new text.

# %%
#Model training using decision tree model
svc = SVC(kernel='rbf')
svc.fit(x_train, y_train)
# Out:
# SVC()

# %%
#testing
svc_pred = svc.predict(x_test)

# %%
#predicting sentiments for the unseen test dataset
svc.fit(X,y)
svc_pred_test = svc.predict(bow_test)

# %%
#result of the prediction
result_svc = pd.DataFrame(svc_pred_test, columns= ['sentiment'])
result_svc.head(20)
# Out:
#     sentiment
# 0           1
# 1           1
# 2           1
# 3           1
# 4           0
# 5           1
# 6           1
# 7           2
# 8           2
# 9           1
# 10         -1
# 11          1
# 12          1
# 13          2
# 14          0
# 15          0
# 16          1
# 17          1
# 18          1
# 19          2

# %%
#creating submission file for kaggle upload
output = pd.DataFrame({"tweetid":df_test['tweetid']})
submission_svc = output.join(result_svc)
submission_svc.to_csv("submission_svc.csv", index = False)

# %%
#pickling the model and storing for later use during the app development
model_save_path = "svc_model.pkl"
with open(model_save_path,'wb') as file:
    pickle.dump(svc,file)

# %% [markdown]
# ### 5.5. Voting Ensemble Classification Model

# %% [markdown]
# A voting classifier is a machine learning estimator that trains various base models or estimators and predicts on the basis of aggregating the findings of each base estimator. In this particular task, we are going to combine the Linear Regression model, the decision tree and the support vector machine model.

# %%
#Model training using voting ensemble model
model_ensemble = VotingClassifier(estimators=[('lr', model), ('dt', tree), ("svm", svc)], voting='hard')
model_ensemble.fit(x_train,y_train)
# Out:
# VotingClassifier(estimators=[('lr', LogisticRegression(multi_class='ovr')),
#                              ('dt', DecisionTreeClassifier(random_state=42)),
#                              ('svm', SVC())])

# %%
#testing
ensmb_pred = model_ensemble.predict(x_test)

# %%
#predicting sentiments for the unseen test dataset
model_ensemble.fit(X,y)
esmb_pred_test = model_ensemble.predict(bow_test)

# %%
#result of the prediction
result_esmb = pd.DataFrame(esmb_pred_test, columns= ['sentiment'])
result_esmb.head(20)
# Out:
#     sentiment
# 0           1
# 1           1
# 2           1
# 3           1
# 4           0
# 5           1
# 6           1
# 7           1
# 8           2
# 9           1
# 10         -1
# 11          1
# 12          1
# 13          2
# 14          0
# 15          0
# 16          1
# 17          1
# 18          1
# 19          2

# %%
#creating submission file for kaggle upload
output = pd.DataFrame({"tweetid":df_test['tweetid']})
submission_esmb = output.join(result_esmb)
submission_esmb.to_csv("submission_esmb.csv", index = False)

# %% [markdown]
# ### 5.6. XGBOOST Classification Model

# %% [markdown]
# XGBoost is an optimized distributed gradient boosting library designed to be highly efficient, flexible and portable. It implements machine learning algorithms under the Gradient Boosting framework.

# %%
#Model training using xgboost model
model_xgb = XGBClassifier()
model_xgb.fit(x_train, y_train)
# Out:
# XGBClassifier(objective='multi:softprob')

# %%
#testing
xgb_pred = model_xgb.predict(x_test)

# %%
#predicting sentiments for the unseen test dataset
model_xgb.fit(x_train,y_train)
xgb_pred_test = model_xgb.predict(bow_test)

# %%
#result of the prediction
result_xgb = pd.DataFrame(xgb_pred_test, columns= ['sentiment'])
result_xgb.head(20)
# Out:
#     sentiment
# 0           1
# 1           1
# 2           1
# 3           1
# 4           0
# 5           2
# 6           0
# 7           2
# 8           2
# 9           2
# 10          2
# 11          1
# 12          1
# 13          2
# 14          1
# 15          0
# 16          1
# 17          1
# 18          1
# 19          2

# %%
#creating submission file for kaggle upload
output = pd.DataFrame({"tweetid":df_test['tweetid']})
submission_xgb = output.join(result_xgb)
submission_xgb.to_csv("submission_xgb.csv", index = False)

# %% [markdown]
# <a id="six"></a>
# # 6. Model Performance
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Model performance ⚡ |
# | :--------------------------- |
# | In this section the relative performance of the various trained ML models on a holdout dataset was carried out.
# ---

# %% [markdown]
# ## 6.1. Classification Report

# %% [markdown]
# A classification report is a performance evaluation metric in machine learning. It is used to show the precision, recall, F1 Score, and support of our trained classification model.
# In the classification report, we will be working with the following metrics;
#
# Precision: Precision is the accuracy of positive predictions.
# $$ Precision = \frac{TP}{TP \space + FP} $$
#
# Recall: Recall is the fraction of positives that were correctly identified.
# $$ Recall = \frac{TP}{TP \space + FN}$$
#
# F1-score: is a weighted harmonic mean of precision and recall such that the best score is 1.0 and the worst is 0.0.
# $$F_1 = 2 \times \frac {Precision \space \times \space Recall }{Precision \space + \space Recall }$$
#
# Support: Support is the number of actual occurrences of the class in the specified dataset

# %% [markdown]
# To carry out the classification reports for all our models, we need to create a function for that.

# %%
#Creating function for checking model performance
def get_class_report(y_test, y_predict):
    '''function for carrying out classification report'''
    
    accuracy = classification_report(y_test, y_predict)
    return accuracy

# %% [markdown]
# ### 6.1.1. Logistic Regression Classification Report

# %%
#Checking Logistics Regression model performance
print(get_class_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.75      0.70      0.72      2092
#            0       0.65      0.70      0.67      2102
#            1       0.82      0.80      0.81      2132
#            2       0.85      0.85      0.85      2204
#
#     accuracy                           0.76      8530
#    macro avg       0.77      0.76      0.76      8530
# weighted avg       0.77      0.76      0.77      8530

# %% [markdown]
# From this report, we can see the precision and f1-score on the 0 class is the lowest, which indicates our logistic regression did not train so well on all classes equally. However, the weighted f1-score which is the most important metric shows that the logistic regression model performed at an accuracy of 0.76 on our classes.

# %% [markdown]
# ### 6.1.2. Catboost Classification Report

# %%
#Checking Catboost Classification model performance
print(get_class_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.73      0.80      0.76      2102
#            0       0.72      0.59      0.65      2101
#            1       0.79      0.74      0.76      2161
#            2       0.76      0.86      0.80      2166
#
#     accuracy                           0.75      8530
#    macro avg       0.75      0.75      0.75      8530
# weighted avg       0.75      0.75      0.75      8530

# %% [markdown]
# From this report, we can see the precision, recall and f1-score on the 0 class is the lowest, which indicates our catboost classification model did not train so well on all classes equally. However, the weighted f1-score which is the most important metric shows that the catboost classification model performed at an accuracy of 0.75 on our classes, which shows it performed less than the logistic regression model. Due to this, the catboost is already not our best model.

# %% [markdown]
# ### 6.1.3. Decision Tree Classification Report

# %%
#Checking Decision Tree Classification model performance
print(get_class_report(y_test, tree_pred))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.77      0.86      0.81      2102
#            0       0.73      0.72      0.72      2101
#            1       0.74      0.66      0.70      2161
#            2       0.82      0.82      0.82      2166
#
#     accuracy                           0.76      8530
#    macro avg       0.76      0.77      0.76      8530
# weighted avg       0.76      0.76      0.76      8530

# %% [markdown]
# From this report, we can see the precision and f1-score on all classes almost performed equally except the recall for 1 class. However, the weighted f1-score which is the most important metric shows that the decision tree classification model performed at an accuracy of 0.76 on our classes.

# %% [markdown]
# ### 6.1.4. Support Vector Machine Classification Report

# %%
#Checking Support Vector Machine Classification model performance
print(get_class_report(y_test, svc_pred))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.79      0.79      0.79      2092
#            0       0.80      0.67      0.73      2102
#            1       0.76      0.88      0.82      2132
#            2       0.86      0.86      0.86      2204
#
#     accuracy                           0.80      8530
#    macro avg       0.80      0.80      0.80      8530
# weighted avg       0.80      0.80      0.80      8530

# %% [markdown]
# From this report, we can see the precision and f1-score on all classes almost performed equally and excellently except the recall for 0 class. However, the weighted f1-score which is the most important metric shows that the decision tree classification model performed at an accuracy of 0.80 on our classes. This is our best performing model so far.

# %% [markdown]
# ### 6.1.5. Voting Ensemble Classification Report

# %%
#Checking voting ensemble classification model performance
print(get_class_report(y_test, ensmb_pred))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.77      0.84      0.80      2102
#            0       0.78      0.68      0.73      2101
#            1       0.79      0.82      0.81      2161
#            2       0.87      0.86      0.86      2166
#
#     accuracy                           0.80      8530
#    macro avg       0.80      0.80      0.80      8530
# weighted avg       0.80      0.80      0.80      8530

# %% [markdown]
# From this report, we can see the precision and f1-score on all classes almost performed equally and excellently except the recall for 0 class. However, the weighted f1-score which is the most important metric shows that the decision tree classification model performed at an accuracy of 0.80 on our classes. With the SVM model, this is our best performing model so far.

# %% [markdown]
# ### 6.1.6. XGBOOST Classification

# %%
#Checking xgboost classification model performance
print(get_class_report(y_test, xgb_pred))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.92      0.74      0.82      2102
#            0       0.75      0.67      0.71      2101
#            1       0.68      0.70      0.69      2161
#            2       0.69      0.87      0.77      2166
#
#     accuracy                           0.75      8530
#    macro avg       0.76      0.75      0.75      8530
# weighted avg       0.76      0.75      0.75      8530

# %% [markdown]
# From this report, we can see the precision for the 1 class is the lowest while recall for the 0 class is the lowest, which indicates our xgboost classification model did not train so well on all classes equally. However, the weighted f1-score which is the most important metric shows that the xgboost classification model performed at an accuracy of 0.75 on our classes, which shows it performed less than the SVM model and voting ensemble model. Due to this, the catboost is not our best model.

# %% [markdown]
# ## 6.2. Saving Model Performance to Comet

# %% [markdown]
# In this section, we are going to save our model performance with the help of comet. This is done seperately in order to keep our work neat.

# %% [markdown]
# ### 6.2.1. Logistic Regression Model Performance

# %%
# Saving each metric to add to a dictionary for logging
f1 = f1_score(y_test, pred, pos_label='positive', average='micro')
precision = precision_score(y_test, pred, pos_label='positive', average='micro')
recall = recall_score(y_test, pred, pos_label='positive', average='micro')

# %%
# Create dictionaries for the data we want to log

params = {"random_state": 42,
          "model_type": "logreg",
          "scaler": "standard scaler",
          "stratify": True
          }
metrics = {"f1": f1,
           "recall": recall,
           "precision": precision
           }

# %%
# Log our parameters and results
experiment.log_parameters(params)
experiment.log_metrics(metrics)

# %%
#end the experiment
experiment.end()
# Out:
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.ml/emmantheo/climate-change-sentiment-analysis-2022/428cbaa7d5d6405fb7c04138d29a29a4
# COMET INFO:   Metrics:
# COMET INFO:     f1        : 0.7623681125439626
# COMET INFO:     precision : 0.7623681125439625
# COMET INFO:     recall    : 0.7623681125439625
# COMET INFO:   Parameters:
# COMET INFO:     model_type   : logreg
# COMET INFO:     random_state : 42
# COMET INFO:     scaler       : standard scaler
# COMET INFO:     stratify     : True
# COMET INFO:   Uploads:
# COMET INFO:     conda-info               : 1
# COMET INFO:     conda-specification      : 1
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# ...

# %% [markdown]
# ### 6.2.2. Decision Tree Model Performance

# %%
# Saving each metric to add to a dictionary for logging
f1 = f1_score(y_test, tree_pred, pos_label='positive', average='micro')
precision = precision_score(y_test, tree_pred, pos_label='positive', average='micro')
recall = recall_score(y_test, tree_pred, pos_label='positive', average='micro')

# %%
# Create dictionaries for the data we want to log

params = {"random_state": 42,
          "model_type": "tree",
          "scaler": "standard scaler",
          "stratify": True
          }
metrics = {"f1": f1,
           "recall": recall,
           "precision": precision
           }

# %%
# Log our parameters and results
experiment.log_parameters(params)
experiment.log_metrics(metrics)

# %%
#end the experiment
experiment.end()
# Out:
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.ml/emmantheo/climate-change-sentiment-analysis-2022/f5aed1aa334f477e92d6fc31353299ab
# COMET INFO:   Metrics:
# COMET INFO:     f1        : 0.7648300117233295
# COMET INFO:     precision : 0.7648300117233294
# COMET INFO:     recall    : 0.7648300117233294
# COMET INFO:   Parameters:
# COMET INFO:     model_type   : tree
# COMET INFO:     random_state : 42
# COMET INFO:     scaler       : standard scaler
# COMET INFO:     stratify     : True
# COMET INFO:   Uploads:
# COMET INFO:     conda-info               : 1
# COMET INFO:     conda-specification      : 1
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# ...

# %% [markdown]
# ### 6.2.3. Catboost Model Performance

# %%
# Saving each metric to add to a dictionary for logging
f1 = f1_score(y_test, y_pred, pos_label='positive', average='micro')
precision = precision_score(y_test, y_pred, pos_label='positive', average='micro')
recall = recall_score(y_test, y_pred, pos_label='positive', average='micro')

# %%
# Create dictionaries for the data we want to log

params = {"random_state": 42,
          "model_type": "catbst",
          "scaler": "standard scaler",
          "stratify": True
          }
metrics = {"f1": f1,
           "recall": recall,
           "precision": precision
           }

# %%
# Log our parameters and results
experiment.log_parameters(params)
experiment.log_metrics(metrics)

# %%
#end the experiment
experiment.end()
# Out:
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.ml/emmantheo/climate-change-sentiment-analysis-2022/6554d131fec3496c998c3dc069063618
# COMET INFO:   Metrics:
# COMET INFO:     f1        : 0.7488862837045721
# COMET INFO:     precision : 0.7488862837045721
# COMET INFO:     recall    : 0.7488862837045721
# COMET INFO:   Parameters:
# COMET INFO:     model_type   : catbst
# COMET INFO:     random_state : 42
# COMET INFO:     scaler       : standard scaler
# COMET INFO:     stratify     : True
# COMET INFO:   Uploads:
# COMET INFO:     conda-info               : 1
# COMET INFO:     conda-specification      : 1
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# ...

# %% [markdown]
# ### 6.2.4. Support Vector Machine Performance

# %%
# Saving each metric to add to a dictionary for logging
f1 = f1_score(y_test, svc_pred, pos_label='positive', average='micro')
precision = precision_score(y_test, svc_pred, pos_label='positive', average='micro')
recall = recall_score(y_test, svc_pred, pos_label='positive', average='micro')

# %%
# Create dictionaries for the data we want to log

params = {"random_state": 42,
          "model_type": "svc",
          "scaler": "standard scaler",
          "stratify": True
          }
metrics = {"f1": f1,
           "recall": recall,
           "precision": precision
           }

# %%
# Log our parameters and results
experiment.log_parameters(params)
experiment.log_metrics(metrics)

# %%
#end the experiment
experiment.end()
# Out:
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.ml/emmantheo/climate-change-sentiment-analysis-2022/0d84685b9a26414f8d3c2a43cd41fa79
# COMET INFO:   Metrics:
# COMET INFO:     f1        : 0.7906213364595546
# COMET INFO:     precision : 0.7906213364595546
# COMET INFO:     recall    : 0.7906213364595546
# COMET INFO:   Parameters:
# COMET INFO:     model_type   : svc
# COMET INFO:     random_state : 42
# COMET INFO:     scaler       : standard scaler
# COMET INFO:     stratify     : True
# COMET INFO:   Uploads:
# COMET INFO:     conda-info               : 1
# COMET INFO:     conda-specification      : 1
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# ...

# %% [markdown]
# ### 6.2.5. Voting Ensemble Classification Model

# %%
# Saving each metric to add to a dictionary for logging
f1 = f1_score(y_test, ensmb_pred, pos_label='positive', average='micro')
precision = precision_score(y_test, ensmb_pred, pos_label='positive', average='micro')
recall = recall_score(y_test, ensmb_pred, pos_label='positive', average='micro')

# %%
# Create dictionaries for the data we want to log

params = {"random_state": 42,
          "model_type": "model_ensemble",
          "scaler": "standard scaler",
          "stratify": True
          }
metrics = {"f1": f1,
           "recall": recall,
           "precision": precision
           }

# %%
# Log our parameters and results
experiment.log_parameters(params)
experiment.log_metrics(metrics)

# %%
#end the experiment
experiment.end()
# Out:
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.ml/emmantheo/climate-change-sentiment-analysis-2022/dfa98af92bca48299b3fed5dfc4f25ec
# COMET INFO:   Metrics:
# COMET INFO:     f1        : 0.8018757327080891
# COMET INFO:     precision : 0.8018757327080891
# COMET INFO:     recall    : 0.8018757327080891
# COMET INFO:   Parameters:
# COMET INFO:     model_type   : model_ensemble
# COMET INFO:     random_state : 42
# COMET INFO:     scaler       : standard scaler
# COMET INFO:     stratify     : True
# COMET INFO:   Uploads:
# COMET INFO:     conda-info               : 1
# COMET INFO:     conda-specification      : 1
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# ...

# %% [markdown]
# ### 6.2.6. XGBOOST Classification Model Performance

# %%
# Saving each metric to add to a dictionary for logging
f1 = f1_score(y_test, xgb_pred, pos_label='positive', average='micro')
precision = precision_score(y_test, xgb_pred, pos_label='positive', average='micro')
recall = recall_score(y_test, xgb_pred, pos_label='positive', average='micro')

# %%
# Create dictionaries for the data we want to log

params = {"random_state": 42,
          "model_type": "model_xgb",
          "scaler": "standard scaler",
          "stratify": True
          }
metrics = {"f1": f1,
           "recall": recall,
           "precision": precision
           }

# %%
# Log our parameters and results
experiment.log_parameters(params)
experiment.log_metrics(metrics)

# %%
#end the experiment
experiment.end()
# Out:
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.ml/emmantheo/climate-change-sentiment-analysis-2022/8db232e6a09349079ff937ae663921a9
# COMET INFO:   Metrics:
# COMET INFO:     f1        : 0.746189917936694
# COMET INFO:     precision : 0.746189917936694
# COMET INFO:     recall    : 0.746189917936694
# COMET INFO:   Parameters:
# COMET INFO:     model_type   : model_xgb
# COMET INFO:     random_state : 42
# COMET INFO:     scaler       : standard scaler
# COMET INFO:     stratify     : True
# COMET INFO:   Uploads:
# COMET INFO:     conda-info               : 1
# COMET INFO:     conda-specification      : 1
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# ...

# %% [markdown]
# <a id="seven"></a>
# ## 7. Model Explanations
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Model explanation ⚡ |
# | :--------------------------- |
# | In this section, we discussed how the best performing model works in a simple way so that both technical and non-technical stakeholders can grasp the intuition behind the model's inner workings. |
#
# ---

# %% [markdown]
# Support Vector Machine and the voting ensemble model performed best, but our best performing model is the Support Vector Machine because it performed better on the unseen test dataset unlike the voting ensemble model that had problem of overfitting.
#
# The SVM works by mapping the dataset to a high-dimensional feature space so that points in the data can be categorized, even when the data are not otherwise linearly separable. A separator between the categories is found, then the data are transformed in such a way that the separator could be drawn as a hyperplane. Following this, characteristics of new data can be used to predict the group to which a new record should belong. Unlike tasks with two different kinds of data points, this particular task has more than two different data points, which means the decision boundary that is going to help us classify these data points is an hyperplane.
#
# Most importantly, the support vector machine performs very well on multiclassification problems, since we are dealing with four classes in our task, the support vector machine performed better on this task better than all other models.

# %% [markdown]
# <a id="seven"></a>
# ## 8. Conclusion
# <a class="anchor" id="1.1"></a>
# <a href=#cont>Back to Table of Contents</a>
#
# ---
#
# | ⚡ Description: Model explanation ⚡ |
# | :--------------------------- |
# | In this section, you are required to discuss how the best performing model works in a simple way so that both technical and non-technical stakeholders can grasp the intuition behind the model's inner workings. |
#
# ---

# %% [markdown]
# In this task, we were able to get insight into the data we are dealing with and after discovering it is a text dataset, we decided to clean the dataset with the use of Natural Language Processor(NLP) in order for the dataset to be ready for training. Both the train and test dataset went throgh the same phases of cleaning. Removal of stopwords was not carried out in this task because removing words like, "against", "isn't", "doesn't" and "not" are going to affect the training of our model because these words are important.
#
# After cleaning, the dataset(message column) which was in text was transformed to numerical data with the help of a count vectoriser. The Vectoriser was set at maximum features of 10000 in order to feed our model a concise number of features for faster and accurate training and prediction. The sentiment feature which is the label was also oversampled(balanced) due to the original data being imbalanced.
#
# After the preprocess and data engineering phase, different models were tried, the models performances were checked with the use of classification report and the Support Vector Machine Model emerged as the best model in terms of prediction and accuracy.
#
# In conclusion, we observed that the train dataset prevented the model from giving more accurate prediction because some of the sentiments attached to the messages were not accuarate. This misled the model during training. Therefore, the more accurate the sentiments in the train data, the better prediction our model is going to have.
